# %% [markdown]
# #Fine-Tuning GPT-3
#
# Copyright 2023 Denis Rothman
#
# [OpenAI fine-tuning documentation](https://beta.openai.com/docs/guides/fine-tuning/)
#
# Run this notebook cell by cell to
#
# 1.prepare data or
# 2.fine-tune a model or
# 3.run a fine-tuned model or
# 4.manage the fine-tunes
#
# Each task can be performed independently in this notebook.
# You can also copy one of the 4 steps in a separate notebook

# %% [markdown]
# ## Installing OpenAI & Wandb
#
# Restart the runtime after installing openai and run the cell again to make sur that "import openai" is executed.

# %%
try:
  import openai
except:
  # !pip install openai
  import openai

# %% [markdown]
# ## Your API Key

# %%
#API Key
#Store you key in a file and read it(you can type it directly in the notebook but it will be visible for somebody next to you)
from google.colab import drive
drive.mount('/content/drive')
f = open("drive/MyDrive/files/api_key.txt", "r")
API_KEY=f.readline()
f.close()

#The OpenAI Key
import os
os.environ['OPENAI_API_KEY'] =API_KEY
openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Optional: Weights and Biases
#
#
#
# Use W&B to build better models faster. Track and visualize all the pieces of your machine learning pipeline, from datasets to production models.
#
# Quickly identify model regressions. Use W&B to visualize results in real time, all in a central dashboard.
# Focus on the interesting ML. Spend less time manually tracking results in spreadsheets and text files.
# Capture dataset versions with W&B Artifacts to identify how changing data affects your resulting models.
# Reproduce any model, with saved code, hyperparameters, launch commands, input data, and resulting model weights.

# %%
try:
  import wandb
except:
  # !pip install wandb
  import wandb

# %% [markdown]
# # 1.Preparing the dataset

# %% [markdown]
# ## 1.1. Preparing the data in JSON

# %%
#From Gutenberg to JSON
import nltk
nltk.download('punkt')
import requests
from bs4 import BeautifulSoup
import json
import re
from nltk.tokenize import sent_tokenize

# First, fetch the text of the book from Project Gutenberg
url = 'http://www.gutenberg.org/cache/epub/4280/pg4280.html'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Get the text of the book and clean it up a bit
text = soup.get_text()
text = re.sub('\s+', ' ', text).strip()

# Split the text into sentences
sentences = sent_tokenize(text)

# Define the separator and ending
prompt_separator = " ->"
completion_ending = "\n"

# Now create the prompts and completions
data = []
for i in range(len(sentences) - 1):
    data.append({
        "prompt": sentences[i] + prompt_separator,
        "completion": " " + sentences[i + 1] + completion_ending
    })

# Write the prompts and completions to a file
with open('kant_prompts_and_completions.json', 'w') as f:
    for line in data:
        f.write(json.dumps(line) + '\n')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import pandas as pd

# Load the data
df = pd.read_json('kant_prompts_and_completions.json', lines=True)
df
# Out:
#                                                  prompt  \
# 0     The Project Gutenberg Etext of The Critique of...
# 1     Be sure to check the copyright laws for your c...
# 2     We encourage you to keep this file, exactly as...
# 3                         Please do not remove this. ->
# 4     This header should be the first thing seen whe...
# ...                                                 ...
# 6122  78-79. is their motto, under which they may le...
# 6123  As regards those who wish to pursue a scientif...
# 6124  When I mention, in relation to the former, the...
# 6125          The critical path alone is still open. ->
# 6126  If my reader has been kind and patient enough ...
#
#                                              completion
# 0      Be sure to check the copyright laws for your ...
# 1      We encourage you to keep this file, exactly a...
# 2                          Please do not remove this.\n
# 3      This header should be the first thing seen wh...
# 4      Do not change or edit it without written perm...
# ...                                                 ...
# 6122   As regards those who wish to pursue a scienti...
# 6123   When I mention, in relation to the former, th...
# 6124           The critical path alone is still open.\n
# 6125   If my reader has been kind and patient enough...
# 6126   End of Project Gutenberg's The Critique of Pu...
#
# [6127 rows x 2 columns]

# %% [markdown]
# ##  1.2. Converting the data to JSONL
#
# Answer "Y" to all of the questions.

# %%
# !openai tools fine_tunes.prepare_data -f "kant_prompts_and_completions.json"
# Out:
# Analyzing...
#
# - Your JSON file appears to be in a JSONL format. Your file will be converted to JSONL format
# - Your file contains 6127 prompt-completion pairs
# - All prompts end with suffix ` ->`
# - All completions end with suffix `\n`
#
# Based on the analysis we will perform the following actions:
# - [Necessary] Your format `JSON` will be converted to `JSONL`
#
#
# Your data will be written to a new JSONL file. Proceed [Y/n]: Y
#
# Wrote modified file to `kant_prompts_and_completions_prepared.jsonl`
# Feel free to take a look!
#
# Now use that file when fine-tuning:
# > openai api fine_tunes.create -t "kant_prompts_and_completions_prepared.jsonl"
#
# After you’ve fine-tuned a model, remember that your prompt has to end with the indicator string ` ->` for the model to start generating completions, rather than continuing with the prompt. Make sure to include `stop=["\n"]` so that the generated texts ends at the expected place.
# Once your model starts training, it'll approximately take 1.44 hours to train a `curie` model, and less for `ada` and `babbage`. Queue will approximately take half an hour per job ahead of you.

# %%
import json

# Open the file and read the lines
with open('kant_prompts_and_completions_prepared.jsonl', 'r') as f:
    lines = f.readlines()

# Parse and print the first 5 lines
for line in lines[:5]:
    data = json.loads(line)
    print(json.dumps(data, indent=4))
# Out:
# {
#     "prompt": "The Project Gutenberg Etext of The Critique of Pure Reason, by Immanuel Kant Copyright laws are changing all over the world. ->",
#     "completion": " Be sure to check the copyright laws for your country before distributing this or any other Project Gutenberg file.\n"
# }
# {
#     "prompt": "Be sure to check the copyright laws for your country before distributing this or any other Project Gutenberg file. ->",
#     "completion": " We encourage you to keep this file, exactly as it is, on your own disk, thereby keeping an electronic path open for future readers.\n"
# }
# {
#     "prompt": "We encourage you to keep this file, exactly as it is, on your own disk, thereby keeping an electronic path open for future readers. ->",
#     "completion": " Please do not remove this.\n"
# }
# {
#     "prompt": "Please do not remove this. ->",
#     "completion": " This header should be the first thing seen when anyone starts to view the etext.\n"
# }
# {
#     "prompt": "This header should be the first thing seen when anyone starts to view the etext. ->",
#     "completion": " Do not change or edit it without written permission.\n"
# }

# %% [markdown]
# kantgpt_prepared.jsonl should now be generated.

# %% [markdown]
# # 2.Fine-tuning a model

# %% [markdown]
# When prompted choose and click on the "ENTER" button.

# %%
# !openai api fine_tunes.create -t "kant_prompts_and_completions_prepared.jsonl" -m "ada"
# Out:
# Found potentially duplicated files with name 'kant_prompts_and_completions_prepared.jsonl', purpose 'fine-tune' and size 2761402 bytes
# file-3lFv23fBQwwNXxxOmpoxESUL
# Enter file ID to reuse an already uploaded file, or an empty string to upload this file anyway:
# Upload progress: 100% 2.76M/2.76M [00:00<00:00, 1.53Git/s]
# Uploaded file from kant_prompts_and_completions_prepared.jsonl: file-b3CAoITXZgD6NpAfAv4pWZY3
# Created fine-tune: ft-sNOmVvZ3fu2cm3XNRCMQuI27
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2023-06-19 17:02:45] Created fine-tune: ft-sNOmVvZ3fu2cm3XNRCMQuI27
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-sNOmVvZ3fu2cm3XNRCMQuI27

# %% [markdown]
# OpenAI has many requests.
# If your steam is interrupted, OpenAI will indicate the instruction to continue fine-tuning.

# %%
# Uncomment this cell to activate the fine_tunes.follow instruction
#!openai api fine_tunes.follow -i [YOUR_FINE_TUNE]

# %% [markdown]
# The kantgpt_prepared_jsonl file, "file-......",  is uploaded and the fine-tune is created:<br>
# "Created fine-tune: ft-............." <br>
# When the fine-tuing is over, copy the fine-tune name in the following cell.

# %% [markdown]
# # 3.Running the fine-tuned GPT-3 model for a completion task
#
# Note: If your fine-tuned model does not appear immediately after the end of the fine-tuning process, you might have to wait until it is processed by OpenAI. You can also:
#
# 1.go to the OpenAI Playground to test your model: https://platform.openai.com/playground
#
# 2.select your model in the dropdown list and test it in that environment

# %%
f = open("drive/MyDrive/files/fine_tune.txt", "r")
FINE_TUNE=f.readline() #load your saved model from a file or load it in this variable
f.close()

# %%
response = openai.Completion.create(
  model=FINE_TUNE, #Your model in FINE_TUNE
  prompt="What did Kant say about a priori concepts: \"We discover there nothing but the confusion and rectifications of philosophical possibility, whereby men thought that the objective consciousness of objects contained in thought was specified and contained in the objects themselves, and therefore that the objects were given by thought as things in themselves\"; or, \"Our conception of a thing gives us nothing but the construction of an object; and nothing what is added to or included in it adds cognition.\" (Both in the former case the conception must be mathematical, in the latter the existence of the object must be inferred.) -> To the pure understanding, therefore, a priori conceptions are still subordinate; they are merely proper forms of intuition, and are used only to represent objects in themselves, and to indicate the relation of the synthesis in their cognitions to each other.\n\nBut this may be explained as follows.\n\n1.\n\nThe functional connection established by our transcendental philosophy is brought out of the pure understanding, which had not the right (brutum) to take it, but rather was put under the weak supervision of the single faculty of the understanding, the mere change of which it does not at present intend to repair.\n\nIn construing any phenomenon, the understanding must remain always in one relation to each of its disjunctions",
  temperature=1,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)

# %%
response
# Out:
# <OpenAIObject text_completion id=cmpl-7TDe9uFIFU8IFrQLMDCo49KYK8w6B at 0x7fa6b4d618f0> JSON: {
#   "id": "cmpl-7TDe9uFIFU8IFrQLMDCo49KYK8w6B",
#   "object": "text_completion",
#   "created": 1687198325,
#   "model": "ada:ft-personal-2023-06-19-17-41-30",
#   "choices": [
#     {
#       "text": ", every wanted element being before removed; for example, everything in a phenomenon may have three possible phenomena (two of which are its cause and an effect, and the effect corresponding to this cause constituting the third).\n\nBut all the formalities of deduction by means of becoming and non-becoming, with which our metaphysical philosophy is full of occasion, and which make abstraction of the different becomings of a given thing without necessary participation in the being of such a thing, are a priori mere matters of understanding, and in no canonical fashion apocryphal; for no sensible phenomenon is more necessary than that the subject of the phenomenon (the substance of the object) should not be an object in itself.\n\n2.\n\nThe natural function of the understanding is to make abstraction of the constants of the synthesis, and to distinguish the arising condition from the rest; just as corporeal phenomenon is considered (in a manner wholly different from ours) as having become as it passes through a certain kind of changes in a certain place, which mode of change, called the birth or death of substance, it always canta.\n\nUltimately the function of the understanding is to consider the objects as things in themselves.\n\nI cannot become a pendent, nor",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 266,
#     "completion_tokens": 256,
#     "total_tokens": 522
#   }
# }

# %%
import textwrap
generated_text = response['choices'][0]['text']

# Remove leading and trailing whitespace
generated_text = generated_text.strip()

# Convert to a pretty paragraph by replacing newline characters with spaces
single_line_response = generated_text.replace('\n', ' ')

# Use textwrap.fill to nicely format the paragraph to wrap at 80 characters (or whatever width you prefer)
wrapped_response = textwrap.fill(single_line_response, width=80)
print(wrapped_response)
# Out:
# , every wanted element being before removed; for example, everything in a
# phenomenon may have three possible phenomena (two of which are its cause and an
# effect, and the effect corresponding to this cause constituting the third).  But
# all the formalities of deduction by means of becoming and non-becoming, with
# which our metaphysical philosophy is full of occasion, and which make
# abstraction of the different becomings of a given thing without necessary
# participation in the being of such a thing, are a priori mere matters of
# understanding, and in no canonical fashion apocryphal; for no sensible
# phenomenon is more necessary than that the subject of the phenomenon (the
# substance of the object) should not be an object in itself.  2.  The natural
# function of the understanding is to make abstraction of the constants of the
# synthesis, and to distinguish the arising condition from the rest; just as
# corporeal phenomenon is considered (in a manner wholly different from ours) as
# having become as it passes through a certain kind of changes in a certain place,
# which mode of change, called the birth or death of substance, it always canta.
# Ultimately the function of the understanding is to consider the objects as
# things in themselves.  I cannot become a pendent, nor

# %%
#!openai api completions.create -m ada:[YOUR_MODEL INFO] -p "Several concepts are a priori such as"

# %% [markdown]
# # 4.Managing the fine_tunes

# %%
# List all created fine-tunes
# !openai api fine_tunes.list > fine_tunes.json

# %%
#displaying the fine_tunes
import json
import pandas as pd

# Load the data
with open('fine_tunes.json') as f:
    data = json.load(f)

# Normalize the data
df = pd.json_normalize(data['data'])  # for pandas >= 1.0.0

df
# Out:
#        object                           id               organization_id  \
# 0   fine-tune  ft-qtHQMnZUBv0baFBR1flx5hsZ  org-h2Kjmcir4wyGtqq1mJALLGIb
# 1   fine-tune  ft-nGWGLgWPTonksokk6c0f2HMS  org-h2Kjmcir4wyGtqq1mJALLGIb
# 2   fine-tune  ft-L3ngtsDSZ3fzGn6ipm33AUsu  org-h2Kjmcir4wyGtqq1mJALLGIb
# 3   fine-tune  ft-lIxhjA4XxmPJ5KORsIGkb9oC  org-h2Kjmcir4wyGtqq1mJALLGIb
# 4   fine-tune  ft-sMSqhlu6PtGiYPpB6MYY7GAo  org-h2Kjmcir4wyGtqq1mJALLGIb
# 5   fine-tune  ft-lKF7fHigF7VrnkR75DDBhgxN  org-h2Kjmcir4wyGtqq1mJALLGIb
# 6   fine-tune  ft-RXueKKisaNy2fCOHJ5qLvPUL  org-h2Kjmcir4wyGtqq1mJALLGIb
# 7   fine-tune  ft-a2TbBRWy7g5n9zoQZmlQnDSi  org-h2Kjmcir4wyGtqq1mJALLGIb
# 8   fine-tune  ft-36tIItJL380NzhEqbMTLR3lv  org-h2Kjmcir4wyGtqq1mJALLGIb
# 9   fine-tune  ft-EEVutXUlc8MZck1RrcbrP2Qc  org-h2Kjmcir4wyGtqq1mJALLGIb
# 10  fine-tune  ft-QQhbcKhX7XrM0Ee5ywpLM7TM  org-h2Kjmcir4wyGtqq1mJALLGIb
# 11  fine-tune  ft-QRcwfEtYarr4iELZllwmKy89  org-h2Kjmcir4wyGtqq1mJALLGIb
# 12  fine-tune  ft-t9bPr5lyb53jjmKovOcEjJ8e  org-h2Kjmcir4wyGtqq1mJALLGIb
# 13  fine-tune  ft-tsXQm35dhJqgCiD2HFpYEEGe  org-h2Kjmcir4wyGtqq1mJALLGIb
# 14  fine-tune  ft-mM5WhT4DVkc19Ffl8GrTmyJv  org-h2Kjmcir4wyGtqq1mJALLGIb
# 15  fine-tune  ft-xAslxMat3FqsbYAYGyXQcaAL  org-h2Kjmcir4wyGtqq1mJALLGIb
# 16  fine-tune  ft-K86JPVaDrftwYUEp9cDRwXjE  org-h2Kjmcir4wyGtqq1mJALLGIb
# 17  fine-tune  ft-yTCETkTrkrvWsGMRQLzBa3Fi  org-h2Kjmcir4wyGtqq1mJALLGIb
# 18  fine-tune  ft-KfXdbGMPimrnezybuFZvnhHh  org-h2Kjmcir4wyGtqq1mJALLGIb
# 19  fine-tune  ft-daprSZy6dWb7KlN6WQxOeS0Y  org-h2Kjmcir4wyGtqq1mJALLGIb
# 20  fine-tune  ft-VWf1reVYMKIUsoVkKTq6wLh5  org-h2Kjmcir4wyGtqq1mJALLGIb
# 21  fine-tune  ft-sNOmVvZ3fu2cm3XNRCMQuI27  org-h2Kjmcir4wyGtqq1mJALLGIb
#
#       model                                     training_files  \
# 0     curie  [{'object': 'file', 'id': 'file-vTxiSW78AF8InU...
# 1       ada  [{'object': 'file', 'id': 'file-02USJi2L1HsPT6...
# 2       ada  [{'object': 'file', 'id': 'file-qimfi96VAFSF0T...
# 3       ada  [{'object': 'file', 'id': 'file-EctKSBtTlrS9NQ...
# 4       ada  [{'object': 'file', 'id': 'file-UinyhlDufZFNu6...
# 5       ada  [{'object': 'file', 'id': 'file-Wv47J7Gb2grLgq...
# 6       ada  [{'object': 'file', 'id': 'file-C0w7OaO5tWvfFP...
# 7       ada  [{'object': 'file', 'id': 'file-Q7NISSHxkCwxEt...
# 8       ada  [{'object': 'file', 'id': 'file-rTZwzsFUTiYm9m...
# 9       ada  [{'object': 'file', 'id': 'file-k7uTTMPn8lxLEq...
# 10      ada  [{'object': 'file', 'id': 'file-nEkywr0j0CgxwB...
# 11      ada  [{'object': 'file', 'id': 'file-yE0EWXO2lmrOGF...
# 12      ada  [{'object': 'file', 'id': 'file-wG79UVZvnpcdVw...
# 13      ada  [{'object': 'file', 'id': 'file-pZWETtHJgAEyDn...
# 14  davinci  [{'object': 'file', 'id': 'file-JujNEuLKbCFJhC...
# 15  davinci  [{'object': 'file', 'id': 'file-Qx2KkMMWXVkY4s...
# 16  davinci  [{'object': 'file', 'id': 'file-8NLJYaS8ccmBYi...
# 17      ada  [{'object': 'file', 'id': 'file-lF5IjxOvC7LyCT...
# 18      ada  [{'object': 'file', 'id': 'file-I2nh6ncmuCfeAK...
# 19      ada  [{'object': 'file', 'id': 'file-6STHZ9DTBvFBPt...
# 20      ada  [{'object': 'file', 'id': 'file-3lFv23fBQwwNXx...
# 21  davinci  [{'object': 'file', 'id': 'file-b3CAoITXZgD6Np...
#
#    validation_files                                       result_files  \
# 0                []  [{'object': 'file', 'id': 'file-UaYjZY2bHGqWuj...
# 1                []  [{'object': 'file', 'id': 'file-UYvXR6E7GbFxZc...
# 2                []  [{'object': 'file', 'id': 'file-YBcjkAQNBPPgvI...
# 3                []  [{'object': 'file', 'id': 'file-Yft1CLk4bbhP2g...
# 4                []  [{'object': 'file', 'id': 'file-tr1TYWkzuCC41m...
# 5                []  [{'object': 'file', 'id': 'file-TEZobr9rL36Ijw...
# 6                []  [{'object': 'file', 'id': 'file-O0zBrRhGS5NsqS...
# 7                []  [{'object': 'file', 'id': 'file-eHtkVJbek6iWpZ...
# 8                []  [{'object': 'file', 'id': 'file-MXPKw0Vmy0Gxc8...
# 9                []  [{'object': 'file', 'id': 'file-34W2ab2B9yZXse...
# 10               []  [{'object': 'file', 'id': 'file-cvoVw2MBRcphDG...
# 11               []  [{'object': 'file', 'id': 'file-SMlrCdy2ZsoGXm...
# 12               []  [{'object': 'file', 'id': 'file-z7WLOh7rrbuVTo...
# 13               []  [{'object': 'file', 'id': 'file-4sqAtdZiDbIl6I...
# 14               []                                                 []
# 15               []                                                 []
# 16               []                                                 []
# 17               []  [{'object': 'file', 'id': 'file-R1B0yFnhUOxxuy...
# 18               []  [{'object': 'file', 'id': 'file-vJU1hfUNyvgt3M...
# 19               []  [{'object': 'file', 'id': 'file-KnyzyuuAx7MQhA...
# 20               []  [{'object': 'file', 'id': 'file-uST4l8Sw0DBGbu...
# 21               []                                                 []
#
#     created_at  updated_at     status  \
# 0   1631135920  1631136239  succeeded
# 1   1631355867  1631355985  succeeded
# 2   1639417780  1639419194  succeeded
# 3   1642591535  1642592973  succeeded
# 4   1644213797  1644215210  succeeded
# 5   1645631464  1645632876  succeeded
# 6   1645632159  1645634283  succeeded
# 7   1645632405  1645635680  succeeded
# 8   1645632710  1645638088  succeeded
# 9   1645632923  1645640485  succeeded
# 10  1645636682  1645641904  succeeded
# 11  1645639351  1645643319  succeeded
# 12  1645643270  1645644741  succeeded
# 13  1645652099  1645653658  succeeded
# 14  1676542409  1676543205     failed
# 15  1676542684  1676543211     failed
# 16  1677838259  1677838694     failed
# 17  1678742946  1678745248  succeeded
# 18  1678743249  1678746440  succeeded
# 19  1682201268  1682203070  succeeded
# 20  1687193600  1687196491  succeeded
# 21  1687194165  1687194479     failed
#
#                                      fine_tuned_model  hyperparams.n_epochs  \
# 0   curie:ft-user-u6to8fv7rsroe5cvku0zfumm-2021-09...                     4
# 1   ada:ft-user-u6to8fv7rsroe5cvku0zfumm-2021-09-1...                     4
# 2   ada:ft-user-u6to8fv7rsroe5cvku0zfumm-2021-12-1...                     4
# 3                 ada:ft-personal-2022-01-19-11-49-27                     4
# 4                 ada:ft-personal-2022-02-07-06-26-44                     4
# 5                 ada:ft-personal-2022-02-23-16-14-30                     4
# 6                 ada:ft-personal-2022-02-23-16-37-57                     4
# 7                 ada:ft-personal-2022-02-23-17-01-14                     4
# 8                 ada:ft-personal-2022-02-23-17-41-22                     4
# 9                 ada:ft-personal-2022-02-23-18-21-20                     4
# 10                ada:ft-personal-2022-02-23-18-44-59                     4
# 11                ada:ft-personal-2022-02-23-19-08-33                     4
# 12                ada:ft-personal-2022-02-23-19-32-15                     4
# 13                ada:ft-personal-2022-02-23-22-00-53                     4
# 14                                               None                     4
# 15                                               None                     4
# 16                                               None                     4
# 17                ada:ft-personal-2023-03-13-22-07-27                     4
# 18                ada:ft-personal-2023-03-13-22-27-18                     4
# 19                ada:ft-personal-2023-04-22-22-37-48                     4
# 20                ada:ft-personal-2023-06-19-17-41-30                     4
# 21                                               None                     4
#
#     hyperparams.batch_size  hyperparams.use_packing  hyperparams.weight_decay  \
# 0                      4.0                      NaN                       0.0
# 1                      4.0                      NaN                       0.0
# 2                     16.0                      NaN                       NaN
# 3                     16.0                      NaN                       NaN
# 4                     16.0                      NaN                       NaN
# 5                     16.0                      NaN                       NaN
# 6                     16.0                      NaN                       NaN
# 7                     16.0                      NaN                       NaN
# 8                     16.0                      NaN                       NaN
# 9                     16.0                      NaN                       NaN
# 10                    16.0                      NaN                       NaN
# 11                    16.0                      NaN                       NaN
# 12                    16.0                      NaN                       NaN
# 13                     8.0                      NaN                       NaN
# 14                     NaN                      NaN                       NaN
# 15                     NaN                      NaN                       NaN
# 16                     NaN                      NaN                       NaN
# 17                    16.0                      NaN                       NaN
# 18                    16.0                      NaN                       NaN
# 19                    16.0                      NaN                       NaN
# 20                     8.0                      NaN                       NaN
# 21                     NaN                      NaN                       NaN
#
#     hyperparams.prompt_loss_weight  hyperparams.learning_rate_multiplier
# 0                             0.10                                  0.10
# 1                             0.10                                  0.10
# 2                             0.10                                  0.10
# 3                             0.10                                  0.05
# 4                             0.10                                  0.05
# 5                             0.10                                  0.05
# 6                             0.10                                  0.05
# 7                             0.10                                  0.05
# 8                             0.10                                  0.05
# 9                             0.10                                  0.05
# 10                            0.10                                  0.05
# 11                            0.10                                  0.05
# 12                            0.10                                  0.05
# 13                            0.10                                  0.05
# 14                            0.01                                   NaN
# 15                            0.01                                   NaN
# 16                            0.01                                   NaN
# 17                            0.01                                  0.10
# 18                            0.01                                  0.10
# 19                            0.01                                  0.10
# 20                            0.01                                  0.10
# 21                            0.01                                   NaN

# %%
# Retrieve a fine-tune and use it in Step 6
#!openai api fine_tunes.get -i [YOUR_MODEL_INFO]
