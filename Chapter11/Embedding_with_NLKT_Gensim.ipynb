# %% [markdown]
# # Embedding with NLKT and Gensim
# Copyright 2023, Denis Rothman

# %% [markdown]
# Installing libraries

# %%
# !pip install --upgrade nltk -qq
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install gensim -qq

# %%
import gensim
print(gensim.__version__)
# Out:
# 4.3.1

# %% [markdown]
# # 1.Reading the text file

# %% [markdown]
# ## Downloading the text file

# %% [markdown]
# Beginning of WIP code until GitHub made public

# %%
from google.colab import drive
drive.mount('/content/drive')
with open("drive/MyDrive/files/github.txt", "r") as f:
      PERSONAL_ACCESS_TOKEN = f.readline().strip()
# Out:
# Mounted at /content/drive

# %%
import requests
url=  'https://raw.githubusercontent.com/Denis2054/Transformers_3rd_Edition/main/Chapter11/Descartes.txt'
output_filename = 'Descartes.txt'
token =  PERSONAL_ACCESS_TOKEN

headers = {
    'Authorization': f'Token {token}'
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    with open(output_filename, 'wb') as file:
        file.write(response.content)
        print('File downloaded successfully.')
else:
    print('Error downloading file.')
# Out:
# File downloaded successfully.

# %% [markdown]
# end of WIP code until book title finalized

# %%
#1.Load Decartes.txt using the Colab file manager
#2.Downloading the file from GitHub
#!curl -L https://raw.githubusercontent.com/Denis2054/Transformers_for_NLP_and_Computer_Vision_3rd_Edition/main/Chapter11/Decartes.txt --output "Decartes.txt"

# %% [markdown]
# ## Reading the text file

# %%
with open('Descartes.txt', 'r', encoding='utf-8') as file:
    descartes_book = file.read().replace('\n', '')

# %% [markdown]
# # 2.Tokenizing the text with punkt

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(descartes_book)

# %% [markdown]
# ## Preprocessing the tokens

# %%
# applying lowercase, removing punctuation and stopwords
#stemming/lemmatization
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

tokens = [lemmatizer.lemmatize(token.lower()) for token in tokens if token.lower() not in stop_words and token not in string.punctuation]
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print(len(tokens))
# Out:
# 9781

# %%
unique_tokens = set(tokens)
print(unique_tokens)
# Out:
# {'pellicle', 'manifested', 'overthrown', 'tothose', 'sodoubtful', 'mine', 'obliged', 'grace', 'draft', 'endeavored', 'indicate', 'ishould', 'treat', 'quitecertain', 'forestall', 'thither', 'whoseexistence', 'circumstanced', 'havehad', 'learnedthem', 'truly', 'andthat', 'lattercurrent', 'allother', 'ofgood', 'counseled', 'entertainingsuch', 'adue', 'credit', 'feigned', 'partialto', 'know', 'parrot', 'begin', 'detect', 'something', 'theschools', 'piece', 'usuallyin', 'appeared', 'toawaken.it', 'ornament', 'ever', 'willnot', 'heartwere', 'room', 'comparison', 'succeeded', 'profess', 'whentheir', 'reason.for', 'sufficientknowledge', 'sixprincipal', 'fly', 'toerror', 'thought', 'tospeak', 'admitted', 'byno', 'whocannot', 'chiefly', 'inadequate', 'artery', 'perceiveanything', 'sciencesby', 'toopinion', 'cavityin', 'nature', 'havingadopted', 'ideasmight', 'feebleresolution', 'employment', 'tosurmount', 'line', 'occasioned', 'execute', 'wepossess', 'ofsatisfaction', 'vanity', 'possessing', 'simple', 'increase', 'entertaining', 'latin', 'inanimate', 'majority', 'clearness', 'trust', 'machine', 'inquired', 'quite', 'legislator', 'anddistinctly', 'areasleep', 'permission', 'new', 'settled', 'effect', 'equally', 'commence', 'provide', 'mere', 'thequestion', 'atthe', 'child', 'bettering', 'requesting', 'revered', 'foster', 'withfreedom', 'assurancethat', 'isthat', 'planetsand', 'perhaps', 'cannotperceive', 'inconvenience', 'occupation', 'ruler', 'theablest', 'speech', 'plurality', 'thehuman', 'thedifferent', 'intensity', 'bringing', 'myprinciples', 'senseor', 'idaily', 'becoming', 'amultitude', 'heard', 'haveventured', 'thatthey', 'contrary', 'account', 'thenumbers', 'savage', 'roomof', 'felt', 'iwas', 'admirablethan', 'makingme', 'makewithout', 'sufficientto', 'advise', 'source', 'qualitiesthat', 'accident', 'whichseveral', 'sea', 'grave', 'extraordinary', 'hypothesis', 'twenty-three', 'persevere', 'field', 'infallibly', 'moreover', 'nointention', 'asummary', 'ifthere', 'removal', 'jaundice', 'designate', 'dreaming', 'conveniently', 'window', 'desirousof', 'probable', 'application.part', 'preceding', 'perfect', 'thusindifferent', 'fancy', 'leftcavity', 'thebody', 'speculation', 'mathematicaldifficulties', 'manyother', 'exercise', 'noother', 'imitating', 'properly', 'chief', 'turnwith', 'conjecture', 'tofollow', 'succeed', 'therest', 'receives', 'fundamental', 'liberty', 'willbe', 'rest', 'returnfrom', 'show', 'itscounterweights', 'hold', 'went', 'thenine', 'description', 'former', 'greatartery', 'provision', 'mostmoderate', 'todoubt', 'rulesi', 'deduction', 'theirtruth.though', 'aconclusion', 'worthsufficiently', 'preferred', 'dumb', 'ascertain', 'insecure', 'andair', 'scruple', 'thetrouble', 'search.in', 'participate', 'sheet', 'mydesign', 'forit', 'impotency', 'grade', 'ordinance', 'height', 'lentit', 'ofpoetry.i', 'thissingle', 'immemorial', 'inholding', 'rigidly', 'kingdom', 'describethe', 'formerly', 'described.but', 'freely', 'strip', 'oughtrather', 'ourbodies', 'expense', 'soearly', 'immediately', 'ido', 'obliges', 'philosophy', 'extended', 'ant', 'discovering', 'follows', 'effected', 'derived', 'remained', 'markedout', 'naturesand', 'time', 'happen', 'beyondour', 'honor', 'whenits', 'respecting', 'moreimportant', 'fromtending', 'doctrine', 'andthereby', 'consideration', 'method', 'prevent', 'manywho', 'thecommon', 'itselfsufficient', 'proceeded', 'thecircumstance', 'algebra', 'specie', 'thiswould', 'compensein', 'wehave', 'morallypossible', 'inour', 'omit', 'firm', 'attain', 'reform', 'offable', 'thehouses', 'duly', 'isalmost', 'notafterwards', 'solitary', 'windpipe', 'commonly', 'error', 'believewill', 'ice', 'asubstance', 'province', 'surround', 'third', 'affection', 'strives', 'convincedthat', 'ergo', 'theproperties', 'object', 'rough', 'becomesuch', 'myignorance', 'moreperfect', 'theadvantages', 'moreworlds', 'compel', 'earth', 'clearlysaw', '’', 'imagine', 'mustinevitably', 'insuch', 'mean', 'next', 'turning', 'heaven', 'inte ...

# %% [markdown]
# # 3.Embedding with Gensim and Word2Vec

# %%
from gensim.models import Word2Vec

# Train a Word2Vec model
model = Word2Vec([tokens],compute_loss=True,vector_size=300,min_count=1)

# Save the model for later use
model.save("descartes_word2vec.model")

# %% [markdown]
# # 4.Model description

# %%
from IPython.display import display
import ipywidgets as widgets

# Load the model
model = Word2Vec.load("descartes_word2vec.model")

# Widget for the model attribute
attr_widget = widgets.Dropdown(
    options=['wv', 'vector_size', 'train_count', 'total_train_time', 'epochs'],
    value='wv',
    description='Attribute:',
)
display(attr_widget)

# Widget for the number of lines
num_lines_widget = widgets.IntSlider(min=0, max=100, step=1, value=10, description='Lines:')
display(num_lines_widget)

# Button to display the data
display_button = widgets.Button(description='Display')
display(display_button)

# Function to display the data
def display_data(button):
    attr = attr_widget.value
    num_lines = num_lines_widget.value

    if attr == 'wv':
        words = list(model.wv.index_to_key)
        for word in words[:num_lines]:
            print(word, model.wv[word])
    else:
        print(getattr(model, attr))

# Link the function to the button
display_button.on_click(display_data)
# Out:
# Dropdown(description='Attribute:', options=('wv', 'vector_size', 'train_count', 'total_train_time', 'epochs'),…
# IntSlider(value=10, description='Lines:')
# Button(description='Display', style=ButtonStyle())

# %%
# Load the model
model = Word2Vec.load("descartes_word2vec.model")

# Print all attributes of the model
for attr in dir(model):
    if not attr.startswith('_'):  # Skip internal attributes
        print(attr)

# %% [markdown]
# # 5.Accessing a Word and vector

# %%
try:
    vector = model.wv['consciousness']
    print('Vector for "consciousness":', vector)
except KeyError:
    print('"consciousness" is not in the dictionary')
# Out:
# "consciousness" is not in the dictionary

# %%
try:
    vector = model.wv['think']
    print('Vector for "think":', vector)
except KeyError:
    print('"think" is not in the dictionary')

# %%
print(len(vector))
# Out:
# 300

# %%
try:
    similar_words = model.wv.most_similar('think')
    print('Most similar words to "think":', similar_words)
except KeyError:
    print('"think" is not in the dictionary')
# Out:
# Most similar words to "think": [('part', 0.23273444175720215), ('heart', 0.2167525440454483), ('oflower', 0.216399148106575), ('dissected', 0.21530592441558838), ('make', 0.21463941037654877), ('object', 0.21401740610599518), ('person', 0.2136993557214737), ('reason', 0.21088391542434692), ('andif', 0.21082493662834167), ('thisopinion', 0.20992112159729004)]

# %%
import ipywidgets as widgets
from IPython.display import display

# Function to get vector
def get_vector(word):
    try:
        vector = model.wv[word]
        print('Vector for "{}":'.format(word), vector)
    except KeyError:
        print('"{}" is not in the dictionary'.format(word))

# Function to get similar words
def get_similar_words(word):
    try:
        similar_words = model.wv.most_similar(word)
        print('Most similar words to "{}":'.format(word))
        for word, similarity in similar_words:
            print('  {}: {:.2f}'.format(word, similarity))
    except KeyError:
        print('"{}" is not in the dictionary'.format(word))

# Create widgets
vector_widget = widgets.interactive(get_vector, word=widgets.Text(placeholder='Type a word'));
similar_words_widget = widgets.interactive(get_similar_words, word=widgets.Text(placeholder='Type a word'));

# Display widgets
display(vector_widget)
display(similar_words_widget)

# %% [markdown]
# # 6.Exploring Gensim's vector space

# %%
for word, index in model.wv.key_to_index.items():
    print(f"Word: {word}, Index: {index}")
# Out:
# Word: one, Index: 0
# Word: truth, Index: 1
# Word: thought, Index: 2
# Word: reason, Index: 3
# Word: may, Index: 4
# Word: could, Index: 5
# Word: heart, Index: 6
# Word: u, Index: 7
# Word: certain, Index: 8
# Word: might, Index: 9
# Word: even, Index: 10
# Word: much, Index: 11
# Word: many, Index: 12
# Word: opinion, Index: 13
# Word: would, Index: 14
# Word: blood, Index: 15
# Word: without, Index: 16
# Word: time, Index: 17
# Word: others, Index: 18
# Word: nature, Index: 19
# Word: since, Index: 20
# Word: body, Index: 21
# Word: object, Index: 22
# Word: men, Index: 23
# Word: must, Index: 24
# Word: thus, Index: 25
# Word: mind, Index: 26
# Word: god, Index: 27
# Word: nothing, Index: 28
# Word: first, Index: 29
# Word: place, Index: 30
# Word: make, Index: 31
# Word: way, Index: 32
# Word: true, Index: 33
# Word: although, Index: 34
# Word: vein, Index: 35
# Word: part, Index: 36
# Word: matter, Index: 37
# Word: two, Index: 38
# Word: thing, Index: 39
# Word: found, Index: 40
# Word: principle, Index: 41
# Word: perhaps, Index: 42
# Word: yet, Index: 43
# Word: order, Index: 44
# Word: le, Index: 45
# Word: able, Index: 46
# Word: science, Index: 47
# Word: upon, Index: 48
# Word: never, Index: 49
# Word: observed, Index: 50
# Word: artery, Index: 51
# Word: mean, Index: 52
# Word: far, Index: 53
# Word: however, Index: 54
# Word: greater, Index: 55
# Word: always, Index: 56
# Word: know, Index: 57
# Word: necessary, Index: 58
# Word: difficulty, Index: 59
# Word: cause, Index: 60
# Word: perfect, Index: 61
# Word: give, Index: 62
# Word: manner, Index: 63
# Word: use, Index: 64
# Word: among, Index: 65
# Word: also, Index: 66
# Word: ofthe, Index: 67
# Word: idea, Index: 68
# Word: better, Index: 69
# Word: knowledge, Index: 70
# Word: take, Index: 71
# Word: life, Index: 72
# Word: say, Index: 73
# Word: particular, Index: 74
# Word: doubt, Index: 75
# Word: error, Index: 76
# Word: sufficient, Index: 77
# Word: like, Index: 78
# Word: method, Index: 79
# Word: account, Index: 80
# Word: good, Index: 81
# Word: ought, Index: 82
# Word: great, Index: 83
# Word: made, Index: 84
# Word: experience, Index: 85
# Word: whose, Index: 86
# Word: think, Index: 87
# Word: single, Index: 88
# Word: different, Index: 89
# Word: general, Index: 90
# Word: wholly, Index: 91
# Word: earth, Index: 92
# Word: state, Index: 93
# Word: course, Index: 94
# Word: light, Index: 95
# Word: unless, Index: 96
# Word: hand, Index: 97
# Word: possessed, Index: 98
# Word: design, Index: 99
# Word: action, Index: 100
# Word: well, Index: 101
# Word: besides, Index: 102
# Word: perfection, Index: 103
# Word: rather, Index: 104
# Word: learned, Index: 105
# Word: animal, Index: 106
# Word: anything, Index: 107
# Word: likewise, Index: 108
# Word: soul, Index: 109
# Word: judgment, Index: 110
# Word: find, Index: 111
# Word: discover, Index: 112
# Word: believe, Index: 113
# Word: example, Index: 114
# Word: public, Index: 115
# Word: least, Index: 116
# Word: rule, Index: 117
# Word: present, Index: 118
# Word: power, Index: 119
# Word: prevent, Index: 120
# Word: accepting, Index: 807
# Word: consists, Index: 808
# Word: compounded, Index: 809
# Word: private, Index: 810
# Word: itcould, Index: 811
# Word: surpass, Index: 812
# Word: befound, Index: 813
# Word: street, Index: 814
# Word: clock, Index: 815
# Word: delay, Index: 816
# Word: thebody, Index: 817
# Word: fact, Index: 818
# Word: practised, Index: 819
# Word: substance, Index: 820
# Word: lost, Index: 821
# Word: heaped, Index: 822
# Word: mature, Index: 823
# Word: happy, Index: 824
# Word: tothis, Index: 825
# Word: allthe, Index: 826
# Word: discipline, Index: 827
# Word: chain, Index: 828
# Word: andsuch, Index: 829
# Word: incomparably, Index: 830
# Word: opposed, Index: 831
# Word: turned, Index: 832
# Word: pellicle, Index: 833
# Word: accurate, Index: 834
# Word: term, Index: 835
# Word: illusion, Index: 836
# Word: due, Index: 837
# Word: returning, Index: 838
# Word: mouth, Index: 839
# Word: andtheir, Index: 840
# Word: ina, Index: 841
# Word: whilst, Index: 842
# Word: commonly, Index: 843
# Word: religion, Index: 844
# Word: correspond, Index: 845
# Word: enumeration, Index: 846
# Word: closedwith, Index: 847
# Word: suffer, Index: 848
# Word: subsisting, Index: 849
# Word: themore, Index: 850
# Word: grandartery, Index: 851
# Word: andin, Index: 852
# Word: auricle, Index: 853
# Word: commencement, Index: 854
# Word: allowed, Index: 855
# Word: warmth, Index: 856
# Word: accustom, Index: 857
# Word: causing, Index: 858
# Word: objectswhich, Index: 859
# Word: mutually, Index: 860
# Word: experienced, Index: 861
# Word: realized, Index: 862
# Word: connected, Index: 863
# Word: judgement, Index: 864
# Word: fly, Index: 865
# Word: health, Index: 866
# Word: wehave, Index: 867
# Word: accomplished, Index: 868
# Word: _vena, Index: 869
# Word: infancy, Index: 870
# Word: perceiving, Index: 871
# Word: contributed, Index: 872
# Word: tree, Index: 873
# Word: possessing, Index: 874
# Word: itwere, Index: 875
# Word: thearterial, Index: 876
# Word: unprejudiced, Index: 877
# Word: inappropriately, Index: 878
# Word: geometry, Index: 879
# Word: inference, Index: 880
# Word: choice, Index: 881
# Word: inthis, Index: 882
# Word: imitating, Index: 883
# Word: meet, Index: 884
# Word: feeble, Index: 885
# Word: uncertain, Index: 886
# Word: whichthe, Index: 887
# Word: presentation, Index: 888
# Word: advancing, Index: 889
# Word: theydesire, Index: 890
# Word: theground, Index: 891
# Word: saying, Index: 892
# Word: shade, Index: 893
# Word: vulgar, Index: 894
# Word: proceeds, Index: 895
# Word: iscomposed, Index: 896
# Word: adding, Index: 897
# Word: reached, Index: 898
# Word: considerable, Index: 899
# Word: seen, Index: 900
# Word: unable, Index: 901
# Word: andbecause, Index: 902
# Word: inquiry, Index: 903
# Word: write, Index: 904
# Word: occur, Index: 905
# Word: conveniently, Index: 906
# Word: establishment, Index: 907
# Word: icannot, Index: 908
# Word: whatever, Index: 909
# Word: majority, Index: 910
# Word: sum, Index: 911
# Word: planet, Index: 912
# Word: inquired, Index: 913
# Word: comprehend, Index: 914
# Word: sound, Index: 915
# Word: sothat, Index: 916
# Word: child, Index: 917
# Word: odor, Index: 918
# Word: godhas, Index: 919
# Word: sight, Index: 920
# Word: happened, Index: 921
# Word: resolvedto, Index: 922
# Word: cast, Index: 923
# Word: hadalready, Index: 924
# Word: aside, Index: 925
# Word: ’, Index: 926
# Word: self, Index: 927
# Word: isone, Index: 928
# Word: todoubt, Index: 929
# Word: exercising, Index: 930
# Word: thanthe, Index: 931
# Word: savage, Index: 932
# Word: numerous, Index: 933
# Word: conscious, Index: 934
# Word: volume, Index: 935
# Word: iremarked, Index: 936
# Word: sleep, Index: 937
# Word: otherwise, Index: 938
# Word: contain, Index: 939
# Word: occupationthan, Index: 940
# Word: reflected, Index: 941
# Word: dream, Index: 942
# Word: head, Index: 943
# Word: clearer, Index: 944
# Word: smaller, Index: 945
# Word: andi, Index: 946
# Word: ten, Index: 947
# Word: pleasure, Index: 948
# Word: absolute, Index: 949
# Word: foundin, Index: 950
# Word: absurd, Index: 951
# Word: prosecuting, Index: 952
# Word: amanner, Index: 953
# Word: hour, Index: 954
# Word: crept, Index: 955
# Word: wander, Index: 956
# Word: follows, Index: 957
# Word: recently, Index: 958
# Word: content, Index: 959
# Word: ofsuch, Index: 960
# Word: refrain, Index: 961
# Word: doubtless, Index: 962
# Word: infrequently, Index: 963
# Word: advance, Index: 964
# Word: treat, Index: 965
# Word: dark, Index: 966
# Word: itwould, Index: 967
# Word: concurrence, Index: 968
# Word: sceptic, Index: 969
# Word: theprinciples, Index: 970
# Word: attaining, Index: 971
# Word: happen, Index: 972
# Word: moderate, Index: 973
# Word: admit, Index: 974
# Word: scruple, Index: 975
# Word: sustains, Index: 976
# Word: comprise, Index: 977
# Word: ishould, Index: 978
# Word: faith, Index: 979
# Word: reformation, Index: 980
# Word: ofwhat, Index: 981
# Word: mere, Index: 982
# Word: interruption, Index: 983
# Word: obscurity, Index: 984
# Word: convert, Index: 985
# Word: consent, Index: 986
# Word: remove, Index: 987
# Word: away, Index: 988
# Word: whereby, Index: 989
# Word: blessing, Index: 990
# Word: prejudicial, Index: 991
# Word: meantime, Index: 992
# Word: devoted, Index: 993
# Word: themembers, Index: 994
# Word: gratification, Index: 995
# Word: begun, Index: 996
# Word: element, Index: 997
# Word: reforming, Index: 998
# Word: changing, Index: 999
# Word: throughout, Index: 1000
# Word: exceedingly, Index: 1001
# Word: founded, Index: 1002
# Word: midst, Index: 1003
# Word: self-instruction, Index: 1004
# Word: adopted, Index: 1005
# Word: diver, Index: 1006
# Word: available, Index: 1007
# Word: foundwithout, Index: 1008
# Word: quite, Index: 1009
# Word: spectator, Index: 1010
# Word: accordingto, Index: 1011
# Word: engage, Index: 1012
# Word: top, Index: 1013
# Word: whati, Index: 1014
# Word: rock, Index: 1015
# Word: bottom, Index: 1016
# Word: seems, Index: 1017
# Word: intelligible, Index: 1018
# Word: comprised, Index: 1019
# Word: thetruth, Index: 1020
# Word: publication, Index: 1021
# Word: hasbeen, Index: 1022
# Word: thanfrom, Index: 1023
# Word: doubted, Index: 1024
# Word: chosen, Index: 1025
# Word: imitated, Index: 1026
# Word: islikewise, Index: 1027
# Word: retirement, Index: 1028
# Word: observable, Index: 1029
# Word: precisely, Index: 1030
# Word: themin, Index: 1031
# Word: restricted, Index: 1032
# Word: produced, Index: 1033
# Word: altogether, Index: 1034
# Word: reserve, Index: 1035
# Word: sea, Index: 1036
# Word: center, Index: 1037
# Word: came, Index: 1038
# Word: operation, Index: 1039
# Word: accomplish, Index: 1040
# Word: holding, Index: 1041
# Word: accorded, Index: 1042
# Word: reputation, Index: 1043
# Word: highway, Index: 1044
# Word: mountain, Index: 1045
# Word: embraced, Index: 1046
# Word: five, Index: 1047
# Word: keep, Index: 1048
# Word: fear, Index: 1049
# Word: impress, Index: 1050
# Word: ihave, Index: 1051
# Word: performance, Index: 1052
# Word: court, Index: 1053
# Word: conducted, Index: 1054
# Word: intercourse, Index: 1055
# Word: differ, Index: 1056
# Word: actually, Index: 1057
# Word: thereasons, Index: 1058
# Word: inferior, Index: 1059
# Word: fellow, Index: 1060
# Word: hesitate, Index: 1061
# Word: persuade, Index: 1062
# Word: reference, Index: 1063
# Word: artisan, Index: 1064
# Word: meansof, Index: 1065
# Word: ability, Index: 1066
# Word: leading, Index: 1067
# Word: thehighest, Index: 1068
# Word: understood, Index: 1069
# Word: mediocrity, Index: 1070
# Word: profit, Index: 1071
# Word: entirely, Index: 1072
# Word: curious, Index: 1073
# Word: accomplishment, Index: 1074
# Word: andthose, Index: 1075
# Word: posterity, Index: 1076
# Word: discovering, Index: 1077
# Word: attain, Index: 1078
# Word: inmaking, Index: 1079
# Word: fancy, Index: 1080
# Word: ofnature, Index: 1081
# Word: controversy, Index: 1082
# Word: instructor, Index: 1083
# Word: inexistence, Index: 1084
# Word: requisite, Index: 1085
# Word: inclination, Index: 1086
# Word: drawn, Index: 1087
# Word: accord, Index: 1088
# Word: consisted, Index: 1089
# Word: esteem, Index: 1090
# Word: theextravagances, Index: 1091
# Word: partly, Index: 1092
# Word: committing, Index: 1093
# Word: tosay, Index: 1094
# Word: continued, Index: 1095
# Word: scarce, Index: 1096
# Word: iam, Index: 1097
# Word: inducement, Index: 1098
# Word: run, Index: 1099
# Word: dispose, Index: 1100
# Word: exceed, Index: 1101
# Word: byanother, Index: 1102
# Word: published, Index: 1103
# Word: distinguish, Index: 1104
# Word: fancied, Index: 1105
# Word: doctrine, Index: 1106
# Word: generality, Index: 1107
# Word: ithought, Index: 1108
# Word: clearness, Index: 1109
# Word: distinctness, Index: 1110
# Word: speculative, Index: 1111
# Word: greatly, Index: 1112
# Word: extraordinary, Index: 1113
# Word: isto, Index: 1114
# Word: require, Index: 1115
# Word: expression, Index: 1116
# Word: theremainder, Index: 1117
# Word: execute, Index: 1118
# Word: sphere, Index: 1119
# Word: toenable, Index: 1120
# Word: ofall, Index: 1121
# Word: derive, Index: 1122
# Word: ofmy, Index: 1123
# Word: touching, Index: 1124
# Word: entire, Index: 1125
# Word: poet, Index: 1126
# Word: thatif, Index: 1127
# Word: reckoned, Index: 1128
# Word: teach, Index: 1129
# Word: hurt, Index: 1130
# Word: borrow, Index: 1131
# Word: close, Index: 1132
# Word: sure, Index: 1133
# Word: enables, Index: 1134
# Word: err, Index: 1135
# Word: childhood, Index: 1136
# Word: despair, Index: 1137
# Word: leisure, Index: 1138
# Word: stupid, Index: 1139
# Word: saw, Index: 1140
# Word: declaration, Index: 1141
# Word: tract, Index: 1142
# Word: parrot, Index: 1143
# Word: put, Index: 1144
# Word: thoughtthat, Index: 1145
# Word: hurtful, Index: 1146
# Word: assuredly, Index: 1147
# Word: notpresume, Index: 1148
# Word: speaking, Index: 1149
# Word: customary, Index: 1150
# Word: speech, Index: 1151
# Word: gathered, Index: 1152
# Word: glory, Index: 1153
# Word: atthe, Index: 1154
# Word: varied, Index: 1155
# Word: contented, Index: 1156
# Word: vain, Index: 1157
# Word: industry, Index: 1158
# Word: battle, Index: 1159
# Word: evidence, Index: 1160
# Word: expectation, Index: 1161
# Word: profession, Index: 1162
# Word: deceived, Index: 1163
# Word: escape, Index: 1164
# Word: movement, Index: 1165
# Word: onthe, Index: 1166
# Word: studying, Index: 1167
# Word: fight, Index: 1168
# Word: wanting, Index: 1169
# Word: ape, Index: 1170
# Word: strong, Index: 1171
# Word: imight, Index: 1172
# Word: ignorance, Index: 1173
# Word: compelled, Index: 1174
# Word: diamond, Index: 1175
# Word: thediscovery, Index: 1176
# Word: ihad, Index: 1177
# Word: andalso, Index: 1178
# Word: toknow, Index: 1179
# Word: friend, Index: 1180
# Word: areendowed, Index: 1181
# Word: emits, Index: 1182
# Word: thataccount, Index: 1183
# Word: hostile, Index: 1184
# Word: agitated, Index: 1185
# Word: irrational, Index: 1186
# Word: travel, Index: 1187
# Word: consistency, Index: 1188
# Word: latin, Index: 1189
# Word: eloquence, Index: 1190
# Word: someother, Index: 1191
# Word: planned, Index: 1192
# Word: six, Index: 1193
# Word: event, Index: 1194
# Word: confess, Index: 1195
# Word: old, Index: 1196
# Word: mistaken, Index: 1197
# Word: dividedinto, Index: 1198
# Word: opening, Index: 1199
# Word: morecorrect, Index: 1200
# Word: bestow, Index: 1201
# Word: occupy, Index: 1202
# Word: ibelieve, Index: 1203
# Word: built, Index: 1204
# Word: third, Index: 1205
# Word: likely, Index: 1206
# Word: theireffects, Index: 1207
# Word: carry, Index: 1208
# Word: promote, Index: 1209
# Word: distilled, Index: 1210
# Word: concealed, Index: 1211
# Word: demonstrated, Index: 1212
# Word: descend, Index: 1213
# Word: gratify, Index: 1214
# Word: dioptrics, Index: 1215
# Word: lie, Index: 1216
# Word: principal, Index: 1217
# Word: winter, Index: 1218
# Word: ibelieved, Index: 1219
# Word: speculation, Index: 1220
# Word: poesy, Index: 1221
# Word: beauty, Index: 1222
# Word: commodious, Index: 1223
# Word: ithas, Index: 1224
# Word: neighborhood, Index: 1225
# Word: thinner, Index: 1226
# Word: command, Index: 1227
# Word: reading, Index: 1228
# Word: donot, Index: 1229
# Word: omit, Index: 1230
# Word: recondite, Index: 1231
# Word: separate, Index: 1232
# Word: note, Index: 1233
# Word: contributing, Index: 1234
# Word: perceive, Index: 1235
# Word: closely, Index: 1236
# Word: endeavoring, Index: 1237
# Word: guard, Index: 1238
# Word: conduce, Index: 1239
# Word: bring, Index: 1240
# Word: constructed, Index: 1241
# Word: intelligence, Index: 1242
# Word: hence, Index: 1243
# Word: cut, Index: 1244
# Word: commit, Index: 1245
# Word: thehuman, Index: 1246
# Word: theology, Index: 1247
# Word: accompanied, Index: 1248
# Word: comparison, Index: 1249
# Word: properly, Index: 1250
# Word: thereasonings, Index: 1251
# Word: converse, Index: 1252
# Word: completed, Index: 1253
# Word: iii, Index: 1254
# Word: tie, Index: 1255
# Word: city, Index: 1256
# Word: share, Index: 1257
# Word: ill, Index: 1258
# Word: withdrawn, Index: 1259
# Word: employ, Index: 1260
# Word: preceptsgave, Index: 1261
# Word: thebriefest, Index: 1262
# Word: inone, Index: 1263
# Word: unraveling, Index: 1264
# Word: ease, Index: 1265
# Word: geometrical, Index: 1266
# Word: morecomplex, Index: 1267
# Word: involved, Index: 1268
# Word: thequestions, Index: 1269
# Word: observance, Index: 1270
# Word: express, Index: 1271
# Word: character, Index: 1272
# Word: littleand, Index: 1273
# Word: affords, Index: 1274
# Word: other.and, Index: 1275
# Word: commencingwith, Index: 1276
# Word: thatphilosophy, Index: 1277
# Word: ascend, Index: 1278
# Word: themathematicians, Index: 1279
# Word: threemonths, Index: 1280
# Word: waspresented, Index: 1281
# Word: wasgiven, Index: 1282
# Word: generaltruths, Index: 1283
# Word: letter, Index: 1284
# Word: familiar, Index: 1285
# Word: admiration, Index: 1286
# Word: all.from, Index: 1287
# Word: openness, Index: 1288
# Word: thatjurisprudence, Index: 1289
# Word: exclude, Index: 1290
# Word: toany, Index: 1291
# Word: toovain, Index: 1292
# Word: andprejudice, Index: 1293
# Word: theircultivators, Index: 1294
# Word: whoever, Index: 1295
# Word: avoid, Index: 1296
# Word: notto, Index: 1297
# Word: ardently, Index: 1298
# Word: attributable, Index: 1299
# Word: foundmyself, Index: 1300
# Word: admitted, Index: 1301
# Word: solutionsof, Index: 1302
# Word: adequatesolution.the, Index: 1303
# Word: completely, Index: 1304
# Word: intoas, Index: 1305
# Word: divide, Index: 1306
# Word: doubt.the, Index: 1307
# Word: theorder, Index: 1308
# Word: asregards, Index: 1309
# Word: desirousof, Index: 1310
# Word: groundof, Index: 1311
# Word: retain, Index: 1312
# Word: wasenabled, Index: 1313
# Word: discoursing, Index: 1314
# Word: ofstudy, Index: 1315
# Word: truthon, Index: 1316
# Word: theextent, Index: 1317
# Word: anaggregate, Index: 1318
# Word: themindividually, Index: 1319
# Word: celebrated, Index: 1320
# Word: forming, Index: 1321
# Word: unsound, Index: 1322
# Word: nointention, Index: 1323
# Word: theperusal, Index: 1324
# Word: interview, Index: 1325
# Word: apprehends, Index: 1326
# Word: hidden, Index: 1327
# Word: attempting, Index: 1328
# Word: particularsciences, Index: 1329
# Word: fertile, Index: 1330
# Word: flourishing, Index: 1331
# Word: howeverdifferent, Index: 1332
# Word: agree, Index: 1333
# Word: beyondour, Index: 1334
# Word: variousrelations, Index: 1335
# Word: ageappeared, Index: 1336
# Word: thenoblest, Index: 1337
# Word: itbest, Index: 1338
# Word: generalform, Index: 1339
# Word: studiedinterview, Index: 1340
# Word: weabstain, Index: 1341
# Word: distaste, Index: 1342
# Word: choicest, Index: 1343
# Word: anypreceding, Index: 1344
# Word: memorable, Index: 1345
# Word: offable, Index: 1346
# Word: deed, Index: 1347
# Word: theschools, Index: 1348
# Word: itmust, Index: 1349
# Word: musthave, Index: 1350
# Word: elevate, Index: 1351
# Word: discretion, Index: 1352
# Word: aid, Index: 1353
# Word: notanticipating, Index: 1354
# Word: deduction, Index: 1355
# Word: tobelieve.i, Index: 1356
# Word: inour, Index: 1357
# Word: accustoming, Index: 1358
# Word: concluding, Index: 1359
# Word: preserve, Index: 1360
# Word: love, Index: 1361
# Word: allother, Index: 1362
# Word: judging, Index: 1363
# Word: referring, Index: 1364
# Word: fill, Index: 1365
# Word: theother, Index: 1366
# Word: tounderstand, Index: 1367
# Word: inquisitive, Index: 1368
# Word: aswell, Index: 1369
# Word: bear, Index: 1370
# Word: theaggregate, Index: 1371
# Word: stir, Index: 1372
# Word: andsequence.and, Index: 1373
# Word: lessen, Index: 1374
# Word: antecedence, Index: 1375
# Word: beentaught, Index: 1376
# Word: numeroushighly, Index: 1377
# Word: beingmore, Index: 1378
# Word: anywhere, Index: 1379
# Word: theremust, Index: 1380
# Word: represented, Index: 1381
# Word: europe, Index: 1382
# Word: exhortation, Index: 1383
# Word: stand, Index: 1384
# Word: intreatises, Index: 1385
# Word: assigning, Index: 1386
# Word: oneby, Index: 1387
# Word: booksthat, Index: 1388
# Word: markedout, Index: 1389
# Word: _last_, Index: 1390
# Word: facilitate, Index: 1391
# Word: withoutby, Index: 1392
# Word: incomparable, Index: 1393
# Word: restricting, Index: 1394
# Word: mostdifficult, Index: 1395
# Word: whichgeometers, Index: 1396
# Word: bethe, Index: 1397
# Word: othershad, Index: 1398
# Word: itsravishing, Index: 1399
# Word: delight, Index: 1400
# Word: rare, Index: 1401
# Word: omitted.the, Index: 1402
# Word: manyrefined, Index: 1403
# Word: andreviews, Index: 1404
# Word: areesteemed, Index: 1405
# Word: legitimately, Index: 1406
# Word: applicable, Index: 1407
# Word: eminently, Index: 1408
# Word: treating, Index: 1409
# Word: advisable, Index: 1410
# Word: ventured, Index: 1411
# Word: beknown, Index: 1412
# Word: actof, Index: 1413
# Word: fix, Index: 1414
# Word: other.also, Index: 1415
# Word: repute, Index: 1416
# Word: chose, Index: 1417
# Word: mostmoderate, Index: 1418
# Word: mostconvenient, Index: 1419
# Word: probably, Index: 1420
# Word: excess, Index: 1421
# Word: isgenerally, Index: 1422
# Word: vicious, Index: 1423
# Word: solelyfrom, Index: 1424
# Word: haveadopted, Index: 1425
# Word: somebeing, Index: 1426
# Word: whatis, Index: 1427
# Word: promisesby, Index: 1428
# Word: distinguishing, Index: 1429
# Word: judgingaright, Index: 1430
# Word: testifying, Index: 1431
# Word: theconviction, Index: 1432
# Word: abridged, Index: 1433
# Word: disapproved, Index: 1434
# Word: provide, Index: 1435
# Word: instability, Index: 1436
# Word: feebleresolution, Index: 1437
# Word: alreadypossess, Index: 1438
# Word: permitengagements, Index: 1439
# Word: vow, Index: 1440
# Word: weknow, Index: 1441
# Word: manyare, Index: 1442
# Word: imitation, Index: 1443
# Word: avigorous, Index: 1444
# Word: generalconsent, Index: 1445
# Word: orin, Index: 1446
# Word: promptitude, Index: 1447
# Word: oftenwished, Index: 1448
# Word: living.for, Index: 1449
# Word: moreperfect, Index: 1450
# Word: noughtbecause, Index: 1451
# Word: convincedthat, Index: 1452
# Word: forsakeit.for, Index: 1453
# Word: thepersians, Index: 1454
# Word: chinese, Index: 1455
# Word: expediency, Index: 1456
# Word: seemedto, Index: 1457
# Word: conformably, Index: 1458
# Word: road, Index: 1459
# Word: theopinions, Index: 1460
# Word: keepalways, Index: 1461
# Word: travelvery, Index: 1462
# Word: oughtrather, Index: 1463
# Word: cognizance, Index: 1464
# Word: aberration, Index: 1465
# Word: excellence, Index: 1466
# Word: theysaid, Index: 1467
# Word: corruption, Index: 1468
# Word: fewdisposed, Index: 1469
# Word: applyit, Index: 1470
# Word: prime, Index: 1471
# Word: notusually, Index: 1472
# Word: everything, Index: 1473
# Word: binding, Index: 1474
# Word: thoseeven, Index: 1475
# Word: ori, Index: 1476
# Word: such.my, Index: 1477
# Word: methodwhich, Index: 1478
# Word: _second_, Index: 1479
# Word: resolute, Index: 1480
# Word: wasable, Index: 1481
# Word: adhere, Index: 1482
# Word: steadfastly, Index: 1483
# Word: doubtful, Index: 1484
# Word: considerationstouching, Index: 1485
# Word: traveler, Index: 1486
# Word: aforest, Index: 1487
# Word: authorif, Index: 1488
# Word: viprefatory, Index: 1489
# Word: oneplace, Index: 1490
# Word: v, Index: 1491
# Word: iv, Index: 1492
# Word: constantly, Index: 1493
# Word: aline, Index: 1494
# Word: direction, Index: 1495
# Word: ii, Index: 1496
# Word: chance, Index: 1497
# Word: prefatory, Index: 1498
# Word: descartescontents, Index: 1499
# Word: rené, Index: 1500
# Word: sciencesby, Index: 1501
# Word: conducting, Index: 1502
# Word: ofmorals, Index: 1503
# Word: fourth, Index: 1504
# Word: itfor, Index: 1505
# Word: whatthe, Index: 1506
# Word: abundantly, Index: 1507
# Word: persevere, Index: 1508
# Word: init, Index: 1509
# Word: security, Index: 1510
# Word: commerce, Index: 1511
# Word: distributed, Index: 1512
# Word: sanction, Index: 1513
# Word: engagementswhere, Index: 1514
# Word: igood, Index: 1515
# Word: write.part, Index: 1516
# Word: reasonsthat, Index: 1517
# Word: idid, Index: 1518
# Word: differencebetween, Index: 1519
# Word: establishes, Index: 1520
# Word: myjudgments, Index: 1521
# Word: pertaining, Index: 1522
# Word: inparticular, Index: 1523
# Word: investigated, Index: 1524
# Word: physical, Index: 1525
# Word: deteriorate, Index: 1526
# Word: deemedit, Index: 1527
# Word: fifth, Index: 1528
# Word: metaphysic, Index: 1529
# Word: grave, Index: 1530
# Word: sin, Index: 1531
# Word: approvedof, Index: 1532
# Word: fullness, Index: 1533
# Word: andreadiness, Index: 1534
# Word: qualitiesthat, Index: 1535
# Word: theoccupations, Index: 1536
# Word: entertained, Index: 1537
# Word: picture, Index: 1538
# Word: abounding, Index: 1539
# Word: thedifficulties, Index: 1540
# Word: delineate, Index: 1541
# Word: thiswould, Index: 1542
# Word: describethe, Index: 1543
# Word: butobserving, Index: 1544
# Word: whengiven, Index: 1545
# Word: principlesborrowed, Index: 1546
# Word: thoughtit, Index: 1547
# Word: suspected, Index: 1548
# Word: delusion, Index: 1549
# Word: knowhow, Index: 1550
# Word: gold, Index: 1551
# Word: littlecopper, Index: 1552
# Word: chosen.after, Index: 1553
# Word: allothers, Index: 1554
# Word: andanticipation, Index: 1555
# Word: dreaded, Index: 1556
# Word: iought, Index: 1557
# Word: approach, Index: 1558
# Word: till, Index: 1559
# Word: andimportant, Index: 1560
# Word: atthat, Index: 1561
# Word: twenty-three, Index: 1562
# Word: mytime, Index: 1563
# Word: thisaccount, Index: 1564
# Word: notless, Index: 1565
# Word: fromcurrent, Index: 1566
# Word: ifthey, Index: 1567
# Word: tale, Index: 1568
# Word: elementsof, Index: 1569
# Word: arithmetic, Index: 1570
# Word: youwill, Index: 1571
# Word: thenumbers, Index: 1572
# Word: ofhuman, Index: 1573
# Word: adherence, Index: 1574
# Word: exact, Index: 1575
# Word: thething, Index: 1576
# Word: includes, Index: 1577
# Word: tocensure, Index: 1578
# Word: ofarithmetic.but, Index: 1579
# Word: prescribe, Index: 1580
# Word: report, Index: 1581
# Word: aspossessed, Index: 1582
# Word: theassurance, Index: 1583
# Word: setthemselves, Index: 1584
# Word: notwith, Index: 1585
# Word: attainable, Index: 1586
# Word: theway, Index: 1587
# Word: describe, Index: 1588
# Word: graduallyhabituated, Index: 1589
# Word: employing.my, Index: 1590
# Word: conception, Index: 1591
# Word: beadded, Index: 1592
# Word: particularmatter, Index: 1593
# Word: preparation, Index: 1594
# Word: entertainingsuch, Index: 1595
# Word: orsense, Index: 1596
# Word: eradicating, Index: 1597
# Word: notremain, Index: 1598
# Word: irresolute, Index: 1599
# Word: graduallyaugmenting, Index: 1600
# Word: tosuspend, Index: 1601
# Word: certaintracks, Index: 1602
# Word: livingthenceforward, Index: 1603
# Word: early, Index: 1604
# Word: felicity, Index: 1605
# Word: provisorycode, Index: 1606
# Word: amdesirous, Index: 1607
# Word: acquainted.the, Index: 1608
# Word: _first_, Index: 1609
# Word: mysingular, Index: 1610
# Word: species.i, Index: 1611
# Word: ornatures, Index: 1612
# Word: obey, Index: 1613
# Word: adheringfirmly, Index: 1614
# Word: accident, Index: 1615
# Word: educatedfrom, Index: 1616
# Word: greaterand, Index: 1617
# Word: regulating, Index: 1618
# Word: thecommon, Index: 1619
# Word: anddistinguishes, Index: 1620
# Word: matteraccording, Index: 1621
# Word: constitutes, Index: 1622
# Word: farthest, Index: 1623
# Word: fromextremes, Index: 1624
# Word: raising, Index: 1625
# Word: commodiously, Index: 1626
# Word: whichwe, Index: 1627
# Word: iiiand, Index: 1628
# Word: mindall, Index: 1629
# Word: erroneous, Index: 1630
# Word: accepted, Index: 1631
# Word: byamassing, Index: 1632
# Word: derivethe, Index: 1633
# Word: useless, Index: 1634
# Word: scarcelyone, Index: 1635
# Word: look, Index: 1636
# Word: enoughof, Index: 1637
# Word: toincreased, Index: 1638
# Word: application.part, Index: 1639
# Word: lowly, Index: 1640
# Word: commencing, Index: 1641
# Word: furnished, Index: 1642
# Word: rebuild, Index: 1643
# Word: thehouse, Index: 1644
# Word: itsuch, Index: 1645
# Word: pulled, Index: 1646
# Word: andbuilders, Index: 1647
# Word: reaped, Index: 1648
# Word: permit, Index: 1649
# Word: durationof, Index: 1650
# Word: plan, Index: 1651
# Word: beforehand, Index: 1652
# Word: brief, Index: 1653
# Word: talent, Index: 1654
# Word: tobestow, Index: 1655
# Word: severalbuildings, Index: 1656
# Word: insuperstition, Index: 1657
# Word: amiss, Index: 1658
# Word: presently, Index: 1659
# Word: issue, Index: 1660
# Word: interested, Index: 1661
# Word: preposterous, Index: 1662
# Word: thinkof, Index: 1663
# Word: personally, Index: 1664
# Word: fundamentally, Index: 1665
# Word: heis, Index: 1666
# Word: andoverturning, Index: 1667
# Word: amended, Index: 1668
# Word: thoughtwas, Index: 1669
# Word: improvement.for, Index: 1670
# Word: suchreflection, Index: 1671
# Word: project, Index: 1672
# Word: threw, Index: 1673
# Word: differentsituations, Index: 1674
# Word: teaching, Index: 1675
# Word: proving, Index: 1676
# Word: incollecting, Index: 1677
# Word: rank, Index: 1678
# Word: resolve, Index: 1679
# Word: sweep, Index: 1680
# Word: inholding, Index: 1681
# Word: visiting, Index: 1682
# Word: spent, Index: 1683
# Word: undergone, Index: 1684
# Word: scrutinyof, Index: 1685
# Word: punishhim, Index: 1686
# Word: persuadedthat, Index: 1687
# Word: bettersucceed, Index: 1688
# Word: lettersin, Index: 1689
# Word: ourreason, Index: 1690
# Word: othermen, Index: 1691
# Word: busied, Index: 1692
# Word: confidence.it, Index: 1693
# Word: discriminatethe, Index: 1694
# Word: beenguided, Index: 1695
# Word: alone.it, Index: 1696
# Word: pull, Index: 1697
# Word: thehouses, Index: 1698
# Word: truefrom, Index: 1699
# Word: rebuilding, Index: 1700
# Word: differently, Index: 1701
# Word: earnest, Index: 1702
# Word: rendering, Index: 1703
# Word: handsome, Index: 1704
# Word: happensthat, Index: 1705
# Word: ingenuity, Index: 1706
# Word: exerciseof, Index: 1707
# Word: erectingit, Index: 1708
# Word: requiring, Index: 1709
# Word: arefrom, Index: 1710
# Word: foster, Index: 1711
# Word: practicalmoment, Index: 1712
# Word: whentheir, Index: 1713
# Word: danger, Index: 1714
# Word: foundationsare, Index: 1715
# Word: insecure, Index: 1716
# Word: firmly, Index: 1717
# Word: oldfoundations, Index: 1718
# Word: settled, Index: 1719
# Word: materially, Index: 1720
# Word: inconvenience, Index: 1721
# Word: fromtending, Index: 3821
# Word: weight, Index: 3822
# Word: thoughi, Index: 3823
# Word: camenext, Index: 3824
# Word: notappear, Index: 3825
# Word: hadsaid, Index: 3826
# Word: muchrespecting, Index: 3827
# Word: theimmense, Index: 3828
# Word: traverse, Index: 3829
# Word: sunand, Index: 3830
# Word: todemonstrate, Index: 3831
# Word: considerablelength, Index: 3832
# Word: stage, Index: 3833
# Word: digressionat, Index: 3834
# Word: fixed, Index: 3835
# Word: planetsand, Index: 3836
# Word: arrangeitself, Index: 3837
# Word: ofthis, Index: 3838
# Word: showed, Index: 3839
# Word: notobserved, Index: 3840
# Word: moreworlds, Index: 3841
# Word: ﻿discourse, Index: 3842

# %%
from IPython.display import display
import ipywidgets as widgets
from gensim import matutils

# Widget for the first word
word1_widget = widgets.Text(value='', description='Word 1:')
display(word1_widget)

# Widget for the second word
word2_widget = widgets.Text(value='', description='Word 2:')
display(word2_widget)

# Button to calculate similarity
calc_button = widgets.Button(description='Calculate Similarity')
display(calc_button)

# Function to calculate similarity
def calculate_similarity(button):
    word1 = word1_widget.value
    word2 = word2_widget.value

    if word1 not in model.wv or word2 not in model.wv:
        print("One or both words are not in the model's vocabulary.")
        return

    vec1 = model.wv[word1]
    vec2 = model.wv[word2]
    similarity = np.dot(matutils.unitvec(vec1), matutils.unitvec(vec2))
    print(f"The cosine similarity between '{word1}' and '{word2}' is {similarity}.")

# Link the function to the button
calc_button.on_click(calculate_similarity)
# Out:
# Text(value='', description='Word 1:')
# Text(value='', description='Word 2:')
# Button(description='Calculate Similarity', style=ButtonStyle())
# The cosine similarity between 'think' and 'smoke' is 0.04001082479953766.

# %%
#words = ["METHOD","REASON,","TRUTH","RIGHTLY", "SCIENCES","SEEKING"]

# %%
import numpy as np
from gensim import matutils
import pandas as pd

# Define list of words
words = ["method","reason","truth","rightly", "science","seeking"]

# Initialize list to store results
data = []

# Iterate over all pairs of words
for i in range(len(words)):
    for j in range(len(words)):  # changed this line
        word1 = words[i]
        word2 = words[j]

        # Ensure words are in the model's vocabulary
        if word1 not in model.wv or word2 not in model.wv:
            print(f"One or both words ('{word1}', '{word2}') are not in the model's vocabulary.")
            continue

        # Calculate cosine similarity
        vec1 = model.wv[word1]
        vec2 = model.wv[word2]
        similarity = np.dot(matutils.unitvec(vec1), matutils.unitvec(vec2))

        # Convert similarity to distance
        distance = 1 - similarity

        # Append to our results
        data.append({'word1': word1, 'word2': word2, 'distance': distance})

# Create DataFrame and display
df = pd.DataFrame(data)
display(df)
# Out:
#       word1    word2      distance
# 0    method   method  0.000000e+00
# 1    method   reason  9.227734e-01
# 2    method    truth  9.341647e-01
# 3    method  rightly  1.091469e+00
# 4    method  science  9.106471e-01
# 5    method  seeking  1.037626e+00
# 6    reason   method  9.227734e-01
# 7    reason   reason  5.960464e-08
# 8    reason    truth  7.917398e-01
# 9    reason  rightly  9.269378e-01
# 10   reason  science  7.190887e-01
# 11   reason  seeking  1.032570e+00
# 12    truth   method  9.341647e-01
# 13    truth   reason  7.917398e-01
# 14    truth    truth  0.000000e+00
# 15    truth  rightly  9.353041e-01
# 16    truth  science  7.210157e-01
# 17    truth  seeking  1.054346e+00
# 18  rightly   method  1.091469e+00
# 19  rightly   reason  9.269378e-01
# 20  rightly    truth  9.353041e-01
# 21  rightly  rightly  0.000000e+00
# 22  rightly  science  9.920156e-01
# 23  rightly  seeking  9.731263e-01
# 24  science   method  9.106471e-01
# 25  science   reason  7.190887e-01
# 26  science    truth  7.210157e-01
# 27  science  rightly  9.920156e-01
# 28  science  science -1.192093e-07
# 29  science  seeking  9.259301e-01
# 30  seeking   method  1.037626e+00
# 31  seeking   reason  1.032570e+00
# 32  seeking    truth  1.054346e+00
# 33  seeking  rightly  9.731263e-01
# 34  seeking  science  9.259301e-01
# 35  seeking  seeking  0.000000e+00

# %%
# Compute the total distance
total_distance = df['distance'].sum()
print(f'Total distance: {total_distance}')
# Out:
# Total distance: 27.93750872835517

# %% [markdown]
# # 7.Tensorflow Projector
#
# https://projector.tensorflow.org/
#
# To visualize the embeddings with the TensorFlow Embedding Projector, you'll need to create two files:
#
# A **vector** file (usually called vecs.tsv) containing the embeddings.
# A **metadat**a file (usually called meta.tsv) containing the labels, which in this case are the words.
# Here's an example of how to create these files from a gensim Word2Vec model:

# %%
import csv
import os
import numpy as np

# Directory where you want to save the files
LOG_DIR = '/content'
os.makedirs(LOG_DIR, exist_ok=True)

# Get the words and vectors
words = list(model.wv.key_to_index.keys())
vectors = [model.wv[word] for word in words]

# Write the vectors to a .tsv file
with open(os.path.join(LOG_DIR, "vecs.tsv"), 'w', newline='') as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(vectors)

# Write the labels (words) to a separate .tsv file
with open(os.path.join(LOG_DIR, "meta.tsv"), 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows([[word] for word in words])  # No header row

# %% [markdown]
# Once you've run this code, you'll have two files: vecs.tsv and meta.tsv. You can upload these files to the TensorFlow Embedding Projector to visualize your word embeddings.
#
# In the projector, each point in the visualization corresponds to a word. The position of the point is determined by the word's vector, and the label of the point is the word itself.
#
# Make sure that both files are correctly formatted and that they both contain the same number of lines (except for the header line in meta.tsv, if you included it). If you have issues with the files, the projector might not be able to load your data correctly.
#
# Remember that the vectors and labels must be in the same order in their respective files. That's why we get the words and vectors at the same time in the code above, using the same list of keys from the model.

# %%
# !echo "Vectors file (vecs.tsv) size:"
# !wc -l /content/vecs.tsv
# !echo "Metadata file (meta.tsv) size:"
# !wc -l /content/meta.tsv
# Out:
# Vectors file (vecs.tsv) size:
# 3843 /content/vecs.tsv
# Metadata file (meta.tsv) size:
# 3843 /content/meta.tsv

# %% [markdown]
# This code uses the wc -l command to count the number of lines in each file. The output will give you the number of lines in each file, which should match if the files were generated correctly.

# %% [markdown]
# Check the data in your files. You can use the following commands to print the first few lines of your metadata and vector files:

# %%
# !head /content/meta.tsv
# Out:
# one
# truth
# thought
# reason
# may
# could
# heart
# u
# certain
# might
